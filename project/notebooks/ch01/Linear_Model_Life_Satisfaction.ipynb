# %% [markdown]
# <a href="https://colab.research.google.com/github/Luis098765/ml-with-aurelien-geron/blob/main/project/notebooks/ch01/Linear_Model_Life_Satisfaction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Luis098765/ml-with-aurelien-geron.git
# Out:
# Cloning into 'ml-with-aurelien-geron'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 44 (delta 5), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 35.19 KiB | 4.40 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# %cd content/ml-with-aurelien-geron/project/data/
# !ls
# Out:
# /content/ml-with-aurelien-geron/project/data
# gdp_per_capita.csv  ml-with-aurelien-geron  oecd_bli_2015.csv

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model

# %%
#Load the data
oecd_bli = pd.read_csv("oecd_bli_2015.csv", thousands=",")
gdp_per_capita = pd.read_csv("gdp_per_capita.csv", thousands=",", delimiter="\t", encoding="latin1", na_values="n/a")
